# %%
import pandas as pd
import matplotlib
# %matplotlib inline

# %%
foo = pd.read_csv("/work/users/l/s/lswhiteh/timesweeper-experiments/d_simulans/ts_simulans/test_predictions/d_simulans_ssv_minmax_Timesweeper_Reg_aft_selcoeff_test_predictions.csv")
foo.head()
foo.describe()
# Out:
#                rep  true_sel_coeff  pred_sel_coeff
# count   854.000000      854.000000      854.000000
# mean   3613.272834        0.275577        0.263003
# std    2120.101195        0.133626        0.108136
# min      22.000000        0.022708        0.061583
# 25%    1754.000000        0.168299        0.170170
# 50%    3494.500000        0.281813        0.287292
# 75%    5442.750000        0.392463        0.353724
# max    7483.000000        0.498795        0.482347

# %%
foo.plot("true_sel_coeff", lw=0, marker='o')
# Out:
# <AxesSubplot:xlabel='true_sel_coeff'>

# %% [markdown]
# Looks uniform to me
