# %%
import matplotlib.pyplot as plt 
import matplotlib 
# %matplotlib inline 

import numpy as np

# %%
coal_sfs = np.loadtxt("coal_sfs.csv", delimiter=",")
slim_sfs = np.loadtxt("slim_sfs.csv", delimiter=",")[:10]

# %%
print(coal_sfs.shape)
print(slim_sfs.shape)
# Out:
# (10, 401)
# (10, 401)

# %%
#print(np.mean(coal_sfs, axis=0)[:20])
print(coal_sfs[:,:20])
# Out:
# [[    0.  38163.5 17999.5 11664.5  8343.5  6505.   5417.   4138.   3616.5
#    3041.5  2642.   2242.   2142.   1858.5  1689.   1601.5  1319.5  1243.
#    1114.   1137.5]
#  [    0.  37288.5 17608.  11149.5  8252.   6275.5  5015.5  4224.   3597.5
#    3064.   2538.   2303.   2158.5  1963.   1577.   1541.   1318.   1210.5
#    1162.5  1061. ]
#  [    0.  37708.5 17748.5 11696.   8113.   6417.   5124.   4479.5  3506.
#    3066.   2841.5  2390.   2085.   1900.5  1764.5  1517.   1313.5  1342.
#    1180.   1153. ]
#  [    0.  37289.  18063.  11091.5  8384.   6339.   5063.   4176.   3618.
#    2861.   2601.5  2271.   2001.   1916.5  1791.   1483.   1400.5  1239.5
#    1171.5  1142. ]
#  [    0.  37345.5 18188.5 11541.   8444.   6463.5  5299.5  4395.   3465.5
#    3096.5  2576.   2429.   2010.   1869.   1714.5  1592.   1465.   1324.
#    1175.   1099. ]
#  [    0.  37844.5 17402.  11484.   8233.   6434.5  5076.5  4134.5  3506.5
# ...

# %%
print(np.mean(slim_sfs, axis=0)[:20])
# Out:
# [    0.  38042.  17909.5 11370.5  8124.8  6104.1  4897.   3986.9  3304.9
#   2799.9  2399.8  2044.9  1819.6  1600.2  1416.5  1230.1  1127.3  1013.3
#    907.1   813.6]

# %%
print(np.mean())

# %%
plt.plot(range(1, 20), np.mean(coal_sfs, axis=0)[1:20], label="Coalescent")
plt.plot(range(1, 20), np.mean(slim_sfs, axis=0)[1:20], label="SLiM")
plt.legend()
plt.savefig("sfs.jpg")

# %%
plt.plot(range(1, 20), np.mean(coal_sfs, axis=0)[1:20])

# %%
plt.plot(range(1, 20), np.mean(slim_sfs, axis=0)[1:20])
